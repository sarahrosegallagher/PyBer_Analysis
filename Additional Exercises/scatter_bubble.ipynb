# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
#MATLAB SCATTER APPROACH 1: PLT.PLOT()

#use o as parameter inside parentheses to switch line to scatter
plt.plot(x_axis, y_axis, 'o')

# %%
#MATLAB APPROACH 2: PLT.SCATTER

#color, label, switch x and y 
plt.scatter(y_axis, x_axis, color='red', label = 'Chicago')

#labels for axes
plt.xlabel("Date")
plt.ylabel("Fare($)")

#title
plt.title("PyBer Fare by Month")

#legend
plt.legend()

#jan to dec on y 
plt.gca().invert_yaxis()

# %%
#MATLAB BUBBLE 

#bubbles have third factor: size via s = y axis (size vary based on value of fare in USD)

plt.scatter(x_axis, y_axis, s = y_axis_larger)

#adjust by adding multiplier to size, via create list with for loop for each point, use new variable in plt
y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

# %%
#refactor resize w py ist comp technique inside plt.scatter function 
#list comp to replace many for and while loops, faster optimized to patterns 
#format is new_list = [expressionf or item in list if conditional]

plt.scatter(x_axis, y_axis, s =[ i * 3 for i in y_axis])

# %%
#OBJECT ORIENTED SCATTER

fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis)

# %%
#OBJECT ORIENTED SCATTER

fig, ax = plt.subplots()
ax.scatter(y_axis, x_axis, s = [i * 5 for i in y_axis], color = 'skyblue', edgecolors='black', alpha=.8, label = "Boston", linewidth=2)


ax. set_title("PyBer Fare by Month")

ax.set_ylabel ("Month")

ax.set_xlabel ("Fare ($)")

ax.set_xlim(0,50)

ax.invert_yaxis()

ax.legend()
